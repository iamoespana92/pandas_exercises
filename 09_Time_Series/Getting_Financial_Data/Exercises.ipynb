# %% [markdown]
# # Getting Financial Data - Pandas Datareader

# %% [markdown]
# ### Introduction:
#
# This time you will get data from a website.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import requests
import numpy as np
from datetime import timedelta
from datetime import datetime
import pandas_datareader.data as web

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is).

# %%
date_format = "%d/%m/%Y"
inicio = datetime.strptime('01/01/2015', date_format)
fin = datetime.today().strftime('%d-%m-%Y')
fin
# Out:
# '12-02-2022'

# %% [markdown]
# ### Step 3. Get an API key for one of the APIs that are supported by Pandas Datareader, preferably for AlphaVantage.
#
# If you do not have an API key for any of the supported APIs, it is easiest to get one for [AlphaVantage](https://www.alphavantage.co/support/#api-key). (Note that the API key is shown directly after the signup. You do *not* receive it via e-mail.)
#
# (For a full list of the APIs that are supported by Pandas Datareader, [see here](https://pydata.github.io/pandas-datareader/readers/index.html). As the APIs are provided by third parties, this list may change.)

# %%
API = 'BTE9NFB6JDAU4KY1'

# %% [markdown]
# ### Step 4. Use Pandas Datarader to read the daily time series for the Apple stock (ticker symbol AAPL) between 01/01/2015 and today, assign it to df_apple and print it.

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=AAPL&apikey=BTE9NFB6JDAU4KY1'
r = requests.get(url)
apple = r.json()
apple = pd.DataFrame.from_dict(apple, orient='index')
apple.head(10)
# Out:
#                                                         1. Information  \
# Meta Data            Daily Prices (open, high, low, close) and Volumes
# Time Series (Daily)                                                NaN
#
#                     2. Symbol 3. Last Refreshed 4. Output Size 5. Time Zone  \
# Meta Data                AAPL        2022-02-11        Compact   US/Eastern
# Time Series (Daily)       NaN               NaN            NaN          NaN
#
#                                                             2022-02-11  \
# Meta Data                                                          NaN
# Time Series (Daily)  {'1. open': '172.3300', '2. high': '173.0800',...
#
#                                                             2022-02-10  \
# Meta Data                                                          NaN
# Time Series (Daily)  {'1. open': '174.1400', '2. high': '175.4800',...
#
#                                                             2022-02-09  \
# ...

# %% [markdown]
# #### lo que veo es que sólo hay dos filas y 105 columnas y cada una de esas columnas tiene un diccionario dentro. tengo que encontrar la forma de limpiar la info y asignar cada open, high, low, close a una fecha específica. se me ocurre convertir cada uno de los diccionarios que hay para cada fecha en dataframes. me qiedaría con muchismos dataframes

# %% [markdown]
# ### Step 5. Add a new column "stock" to the dataframe and add the ticker symbol

# %% [markdown]
# ### Step 6. Repeat the two previous steps for a few other stocks, always creating a new dataframe: Tesla, IBM and Microsoft. (Ticker symbols TSLA, IBM and MSFT.)

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=BTE9NFB6JDAU4KY1'
r = requests.get(url)
ibm = r.json()
ibm = pd.DataFrame.from_dict(ibm, orient='index')
ibm.head(10)
# Out:
#                                                         1. Information  \
# Meta Data            Daily Prices (open, high, low, close) and Volumes
# Time Series (Daily)                                                NaN
#
#                     2. Symbol 3. Last Refreshed 4. Output Size 5. Time Zone  \
# Meta Data                 IBM        2022-02-11        Compact   US/Eastern
# Time Series (Daily)       NaN               NaN            NaN          NaN
#
#                                                             2022-02-11  \
# Meta Data                                                          NaN
# Time Series (Daily)  {'1. open': '133.9000', '2. high': '134.7099',...
#
#                                                             2022-02-10  \
# Meta Data                                                          NaN
# Time Series (Daily)  {'1. open': '135.4700', '2. high': '136.5600',...
#
#                                                             2022-02-09  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=TSLA&apikey=BTE9NFB6JDAU4KY1'
r = requests.get(url)
tesla = r.json()
tesla = pd.DataFrame.from_dict(tesla, orient='index')
tesla.head(10)
# Out:
#                                                         1. Information  \
# Meta Data            Daily Prices (open, high, low, close) and Volumes
# Time Series (Daily)                                                NaN
#
#                     2. Symbol 3. Last Refreshed 4. Output Size 5. Time Zone  \
# Meta Data                TSLA        2022-02-11        Compact   US/Eastern
# Time Series (Daily)       NaN               NaN            NaN          NaN
#
#                                                             2022-02-11  \
# Meta Data                                                          NaN
# Time Series (Daily)  {'1. open': '909.6300', '2. high': '915.9600',...
#
#                                                             2022-02-10  \
# Meta Data                                                          NaN
# Time Series (Daily)  {'1. open': '908.3700', '2. high': '943.8100',...
#
#                                                             2022-02-09  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MSFT&apikey=BTE9NFB6JDAU4KY1'
r = requests.get(url)
micro = r.json()
micro = pd.DataFrame.from_dict(micro, orient='index')
micro.head(10)
# Out:
#   File "<ipython-input-38-079e92df9183>", line 5
#     micro.dtypes ()
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### Step 7. Combine the four separate dataFrames into one combined dataFrame df that holds the information for all four stocks

# %%
df= apple.append('telsa', 'micro', 'ibm')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-0932b1bfb64f> in <module>
# ----> 1 df= apple.append('telsa', 'micro', 'ibm')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7980             to_concat = [self, other]
#    7981         return (
# -> 7982             concat(
#    7983                 to_concat,
#    7984                 ignore_index=ignore_index,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ...

# %% [markdown]
# ### Step 8. Shift the stock column into the index (making it a multi-level index consisting of the ticker symbol and the date).

# %% [markdown]
# ### Step 7. Create a dataFrame called vol, with the volume values.

# %% [markdown]
# ### Step 8. Aggregate the data of volume to weekly.
# Hint: Be careful to not sum data from the same week of 2015 and other years.

# %% [markdown]
# ### Step 9. Find all the volume traded in the year of 2015
