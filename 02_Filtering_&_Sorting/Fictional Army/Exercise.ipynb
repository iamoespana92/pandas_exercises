# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %% [markdown]
# ### Introduction:
#
# This exercise was inspired by this [page](http://chrisalbon.com/python/)
#
# Special thanks to: https://github.com/chrisalbon for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. This is the data given as a dictionary

# %%
# Create an example dataframe about a fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %%
dic = {'nombres': ['pepe','maria'], 'peso':[60,50]}

# %%
pd.DataFrame(dic)
# Out:
#   nombres  peso
# 0    pepe    60
# 1   maria    50

# %%
pd.DataFrame([['´pepe', '´maria'], [50,60]])
# Out:
#        0       1
# 0  ´pepe  ´maria
# 1     50      60

# %%
pd.DataFrame([['´pepe', '´maria'], [50,60]], columns=['´nombre´s', '´peso'])
# Out:
#   ´nombre´s   ´peso
# 0     ´pepe  ´maria
# 1        50      60

# %% [markdown]
# ### Step 3. Create a dataframe and assign it to a variable called army.
#
# #### Don't forget to include the columns names in the order presented in the dictionary ('regiment', 'company', 'deaths'...) so that the column index order is consistent with the solutions. If omitted, pandas will order the columns alphabetically.

# %%
df = pd.DataFrame(raw_data)
df.sample(5)
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 10      Scouts     2nd      37        8  1099        63          2        1
# 7     Dragoons     2nd      62        3   849        48          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
#
#     deserters      origin
# 10          2    Louisana
# 7          31  Washington
# 4           3       Maine
# 0           4     Arizona
# 3           2     Florida

# %%
df.head()
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 1  Nighthawks     1st      52       42   957         5          2        0
# 2  Nighthawks     2nd      25        2  1099        62          3        1
# 3  Nighthawks     2nd     616        2  1400        26          3        1
# 4    Dragoons     1st      43        4  1592        73          2        0
#
#    deserters      origin
# 0          4     Arizona
# 1         24  California
# 2         31       Texas
# 3          2     Florida
# 4          3       Maine

# %%
df.tail()
# Out:
#     regiment company  deaths  battles  size  veterans  readiness  armored  \
# 7   Dragoons     2nd      62        3   849        48          3        1
# 8     Scouts     1st      62        4   973        48          2        0
# 9     Scouts     1st      73        7  1005       435          1        0
# 10    Scouts     2nd      37        8  1099        63          2        1
# 11    Scouts     2nd      35        9  1523       345          3        1
#
#     deserters      origin
# 7          31  Washington
# 8           2      Oregon
# 9           3     Wyoming
# 10          2    Louisana
# 11          3     Georgia

# %% [markdown]
# ### Step 4. Set the 'origin' colum as the index of the dataframe

# %%
df.set_index('origin')
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
df
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 5     Dragoons     1st     234        7  1006        37          1        1
# 6     Dragoons     2nd     523        8   987       949          2        0
# 7     Dragoons     2nd      62        3   849        48          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# ...

# %%
df.set_index('origin', inplace=True) # df = df.set_index('origin')

# %%
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %% [markdown]
# ### Step 5. Print only the column veterans

# %%
df[['veterans']]
# Out:
#             veterans
# origin
# Arizona            1
# California         5
# Texas             62
# Florida           26
# Maine             73
# Iowa              37
# Alaska           949
# Washington        48
# Oregon            48
# Wyoming          435
# Louisana          63
# Georgia          345

# %% [markdown]
# ## Importance of DataFrame or Series

# %%
s = df.groupby('regiment').deaths.sum()

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# regiment
# Dragoons       862
# Nighthawks    1216
# Scouts         207
# Name: deaths, dtype: int64

# %%
import seaborn as sns

# %%
sns.barplot(s.regiment, s.deaths)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-1b85329383d6> in <module>
# ----> 1 sns.barplot(s.regiment, s.deaths)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'regiment'

# %%
s
# Out:
# regiment
# Dragoons       862
# Nighthawks    1216
# Scouts         207
# Name: deaths, dtype: int64

# %%
s.index
# Out:
# Index(['Dragoons', 'Nighthawks', 'Scouts'], dtype='object', name='regiment')

# %%
s.values
# Out:
# array([ 862, 1216,  207], dtype=int64)

# %%
sns.barplot(x=s.index, y=s.values)
# Out:
# <AxesSubplot:xlabel='regiment'>

# %%
dfs = s.reset_index()

# %%
dfs
# Out:
#      regiment  deaths
# 0    Dragoons     862
# 1  Nighthawks    1216
# 2      Scouts     207

# %%
sns.barplot(x=dfs.regiment, y=dfs.deaths)
# Out:
# <AxesSubplot:xlabel='regiment', ylabel='deaths'>

# %%
df.groupby(['regiment', 'company'])['size'].sum()
# Out:
# regiment    company
# Dragoons    1st        2598
#             2nd        1836
# Nighthawks  1st        2002
#             2nd        2499
# Scouts      1st        1978
#             2nd        2622
# Name: size, dtype: int64

# %%
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
df.groupby(['regiment', 'company']).size.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-35bd117c6286> in <module>
# ----> 1 df.groupby(['regiment', 'company']).size.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
df.groupby(['regiment', 'company']).size()
# Out:
# regiment    company
# Dragoons    1st        2
#             2nd        2
# Nighthawks  1st        2
#             2nd        2
# Scouts      1st        2
#             2nd        2
# dtype: int64

# %%
s = df.groupby(['regiment', 'company'])['size'].sum()

# %%
s
# Out:
# regiment    company
# Dragoons    1st        2598
#             2nd        1836
# Nighthawks  1st        2002
#             2nd        2499
# Scouts      1st        1978
#             2nd        2622
# Name: size, dtype: int64

# %%
s.regiment
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-35f291c2f80f> in <module>
# ----> 1 s.regiment
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'regiment'

# %%
s.reset_index()
# Out:
#      regiment company  size
# 0    Dragoons     1st  2598
# 1    Dragoons     2nd  1836
# 2  Nighthawks     1st  2002
# 3  Nighthawks     2nd  2499
# 4      Scouts     1st  1978
# 5      Scouts     2nd  2622

# %%
dfs = pd.DataFrame(s)

# %%
s
# Out:
# regiment    company
# Dragoons    1st        2598
#             2nd        1836
# Nighthawks  1st        2002
#             2nd        2499
# Scouts      1st        1978
#             2nd        2622
# Name: size, dtype: int64

# %%
dfs
# Out:
#                     size
# regiment   company
# Dragoons   1st      2598
#            2nd      1836
# Nighthawks 1st      2002
#            2nd      2499
# Scouts     1st      1978
#            2nd      2622

# %%
dfs['regiment']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'regiment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-d844f6b2765b> in <module>
# ----> 1 dfs['regiment']
#
# ...

# %%
dfs.regiment
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-e19487b36540> in <module>
# ----> 1 dfs.regiment
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'regiment'

# %%
dfs.columns
# Out:
# Index(['size'], dtype='object')

# %%
dfs.index
# Out:
# MultiIndex([(  'Dragoons', '1st'),
#             (  'Dragoons', '2nd'),
#             ('Nighthawks', '1st'),
#             ('Nighthawks', '2nd'),
#             (    'Scouts', '1st'),
#             (    'Scouts', '2nd')],
#            names=['regiment', 'company'])

# %%
dfs['']

# %%
s
# Out:
# regiment    company
# Dragoons    1st        2598
#             2nd        1836
# Nighthawks  1st        2002
#             2nd        2499
# Scouts      1st        1978
#             2nd        2622
# Name: size, dtype: int64

# %%
s.reset_index()
# Out:
#      regiment company  size
# 0    Dragoons     1st  2598
# 1    Dragoons     2nd  1836
# 2  Nighthawks     1st  2002
# 3  Nighthawks     2nd  2499
# 4      Scouts     1st  1978
# 5      Scouts     2nd  2622

# %%
s.to_frame()
# Out:
#                     size
# regiment   company
# Dragoons   1st      2598
#            2nd      1836
# Nighthawks 1st      2002
#            2nd      2499
# Scouts     1st      1978
#            2nd      2622

# %%
dfs = pd.DataFrame(s)

# %%
dfs
# Out:
#                     size
# regiment   company
# Dragoons   1st      2598
#            2nd      1836
# Nighthawks 1st      2002
#            2nd      2499
# Scouts     1st      1978
#            2nd      2622

# %%
dfs.index.get_level_values(level='regiment')
# Out:
# Index(['Dragoons', 'Dragoons', 'Nighthawks', 'Nighthawks', 'Scouts', 'Scouts'], dtype='object', name='regiment')

# %%
dfs.index.get_level_values(level='regiment')
# Out:
# Index(['Dragoons', 'Dragoons', 'Nighthawks', 'Nighthawks', 'Scouts', 'Scouts'], dtype='object', name='regiment')

# %%
dfs_reset = s.reset_index()

# %%
dfs_reset
# Out:
#      regiment company  size
# 0    Dragoons     1st  2598
# 1    Dragoons     2nd  1836
# 2  Nighthawks     1st  2002
# 3  Nighthawks     2nd  2499
# 4      Scouts     1st  1978
# 5      Scouts     2nd  2622

# %%
dfs_reset.regiment
# Out:
# 0      Dragoons
# 1      Dragoons
# 2    Nighthawks
# 3    Nighthawks
# 4        Scouts
# 5        Scouts
# Name: regiment, dtype: object

# %%
sns.barplot(x=dfs.regiment, y=dfs.deaths, hue=company)
# Out:
# <AxesSubplot:xlabel='regiment', ylabel='deaths'>

# %% [markdown]
# ### Takeaways
#
# 1. no es oro todo lo que reluce
#     - aunque sean los mismos valores, numeros,...
#     - estan de diferente forma

# %%
s
# Out:
# regiment    company
# Dragoons    1st        2598
#             2nd        1836
# Nighthawks  1st        2002
#             2nd        2499
# Scouts      1st        1978
#             2nd        2622
# Name: size, dtype: int64

# %%
s.index
# Out:
# MultiIndex([(  'Dragoons', '1st'),
#             (  'Dragoons', '2nd'),
#             ('Nighthawks', '1st'),
#             ('Nighthawks', '2nd'),
#             (    'Scouts', '1st'),
#             (    'Scouts', '2nd')],
#            names=['regiment', 'company'])

# %%
s.values
# Out:
# array([2598, 1836, 2002, 2499, 1978, 2622], dtype=int64)

# %%
s.index.get_level_values('regiment')
# Out:
# Index(['Dragoons', 'Dragoons', 'Nighthawks', 'Nighthawks', 'Scouts', 'Scouts'], dtype='object', name='regiment')

# %%
a = s.index.get_level_values('company')

# %%
type(a)
# Out:
# pandas.core.indexes.base.Index

# %%
a.name
# Out:
# 'company'

# %%
a
# Out:
# Index(['1st', '2nd', '1st', '2nd', '1st', '2nd'], dtype='object', name='company')

# %%
a.values
# Out:
# array(['1st', '2nd', '1st', '2nd', '1st', '2nd'], dtype=object)

# %%
dfs
# Out:
#                     size
# regiment   company
# Dragoons   1st      2598
#            2nd      1836
# Nighthawks 1st      2002
#            2nd      2499
# Scouts     1st      1978
#            2nd      2622

# %%
dfs_reset
# Out:
#      regiment company  size
# 0    Dragoons     1st  2598
# 1    Dragoons     2nd  1836
# 2  Nighthawks     1st  2002
# 3  Nighthawks     2nd  2499
# 4      Scouts     1st  1978
# 5      Scouts     2nd  2622

# %% [markdown]
# ### Step 6. Print the columns 'veterans' and 'deaths'

# %%
dfp = df.pivot_table(values='deaths', columns=['regiment', 'company'])

# %%
dfp['Dragoons']
# Out:
# company    1st    2nd
# deaths   138.5  292.5

# %%
dfp
# Out:
# regiment Dragoons        Nighthawks        Scouts
# company       1st    2nd        1st    2nd    1st   2nd
# deaths      138.5  292.5      287.5  320.5   67.5  36.0

# %%
dfp['Dragoons', 'Nighthawks']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nighthawks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
# ...

# %%
dfp
# Out:
# regiment Dragoons        Nighthawks        Scouts
# company       1st    2nd        1st    2nd    1st   2nd
# deaths      138.5  292.5      287.5  320.5   67.5  36.0

# %%
dfp['Dragoons']
# Out:
# company    1st    2nd
# deaths   138.5  292.5

# %%
dfp['Dragoons', '1st']
# Out:
# deaths    138.5
# Name: (Dragoons, 1st), dtype: float64

# %%
df[['veterans','deaths']]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Georgia          345      35

# %%
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
df[['veterans','deaths', 'size']]
# Out:
#             veterans  deaths  size
# origin
# Arizona            1     523  1045
# California         5      52   957
# Texas             62      25  1099
# Florida           26     616  1400
# Maine             73      43  1592
# Iowa              37     234  1006
# Alaska           949     523   987
# Washington        48      62   849
# Oregon            48      62   973
# Wyoming          435      73  1005
# Louisana          63      37  1099
# Georgia          345      35  1523

# %%
df['veterans','deaths']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('veterans', 'deaths')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-545734dc35a9> in <module>
# ...

# %%
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
df.regiment
# Out:
# origin
# Arizona       Nighthawks
# California    Nighthawks
# Texas         Nighthawks
# Florida       Nighthawks
# Maine           Dragoons
# Iowa            Dragoons
# Alaska          Dragoons
# Washington      Dragoons
# Oregon            Scouts
# Wyoming           Scouts
# Louisana          Scouts
# Georgia           Scouts
# Name: regiment, dtype: object

# %%
df.regiment.unique()
# Out:
# array(['Nighthawks', 'Dragoons', 'Scouts'], dtype=object)

# %%
df.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters'],
#       dtype='object')

# %%
df.columns.unique()
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters'],
#       dtype='object')

# %% [markdown]
# ### Step 8. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska

# %%
###he tratado de sacar los valores Maine y Alaska poniendolos primero en los corchetes, de las columna mencionadas, pero me da error. Al ser loc, hay que poner los nombres exactos, no sé por qué falla

# %%
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
dfa = df.reset_index()

# %%
dfa
# Out:
#         origin    regiment company  deaths  battles  size  veterans  \
# 0      Arizona  Nighthawks     1st     523        5  1045         1
# 1   California  Nighthawks     1st      52       42   957         5
# 2        Texas  Nighthawks     2nd      25        2  1099        62
# 3      Florida  Nighthawks     2nd     616        2  1400        26
# 4        Maine    Dragoons     1st      43        4  1592        73
# 5         Iowa    Dragoons     1st     234        7  1006        37
# 6       Alaska    Dragoons     2nd     523        8   987       949
# 7   Washington    Dragoons     2nd      62        3   849        48
# 8       Oregon      Scouts     1st      62        4   973        48
# 9      Wyoming      Scouts     1st      73        7  1005       435
# 10    Louisana      Scouts     2nd      37        8  1099        63
# 11     Georgia      Scouts     2nd      35        9  1523       345
#
#     readiness  armored  deserters
# 0           1        1          4
# ...

# %%
dfa.loc[["Maine", "Alaska"], ["deaths", "size", "deserters"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-148-aa9f85ade03d> in <module>
# ----> 1 dfa.loc[["Maine", "Alaska"], ["deaths", "size", "deserters"]]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1065         # ugly hack for GH #836
#    1066         if self._multi_take_opportunity(tup):
# -> 1067             return self._multi_take(tup)
#    1068
#    1069         return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
df.loc[["Maine", "Alaska"], ["deaths", "size", "deserters"]]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %%
dfa
# Out:
#         origin    regiment company  deaths  battles  size  veterans  \
# 0      Arizona  Nighthawks     1st     523        5  1045         1
# 1   California  Nighthawks     1st      52       42   957         5
# 2        Texas  Nighthawks     2nd      25        2  1099        62
# 3      Florida  Nighthawks     2nd     616        2  1400        26
# 4        Maine    Dragoons     1st      43        4  1592        73
# 5         Iowa    Dragoons     1st     234        7  1006        37
# 6       Alaska    Dragoons     2nd     523        8   987       949
# 7   Washington    Dragoons     2nd      62        3   849        48
# 8       Oregon      Scouts     1st      62        4   973        48
# 9      Wyoming      Scouts     1st      73        7  1005       435
# 10    Louisana      Scouts     2nd      37        8  1099        63
# 11     Georgia      Scouts     2nd      35        9  1523       345
#
#     readiness  armored  deserters
# 0           1        1          4
# ...

# %%
dfa.loc[[4, 6], ["deaths", "size", "deserters"]]
# Out:
#    deaths  size  deserters
# 4      43  1592          3
# 6     523   987         24

# %% [markdown]
# ### Step 9. Select the rows 3 to 7 and the columns 3 to 6

# %%
## iloc va por la posicion, loc va en base al nombre de la columna o de la fila

# %%
df.iloc [2:7,2:6]
# Out:
#          deaths  battles  size  veterans
# origin
# Texas        25        2  1099        62
# Florida     616        2  1400        26
# Maine        43        4  1592        73
# Iowa        234        7  1006        37
# Alaska      523        8   987       949

# %%
df.iloc[:, :3]
# Out:
#               regiment company  deaths
# origin
# Arizona     Nighthawks     1st     523
# California  Nighthawks     1st      52
# Texas       Nighthawks     2nd      25
# Florida     Nighthawks     2nd     616
# Maine         Dragoons     1st      43
# Iowa          Dragoons     1st     234
# Alaska        Dragoons     2nd     523
# Washington    Dragoons     2nd      62
# Oregon          Scouts     1st      62
# Wyoming         Scouts     1st      73
# Louisana        Scouts     2nd      37
# Georgia         Scouts     2nd      35

# %% [markdown]
# ### Step 10. Select every row after the fourth row and all columns

# %%
df.iloc[4:,:]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Maine       Dragoons     1st      43        4  1592        73          2
# Iowa        Dragoons     1st     234        7  1006        37          1
# Alaska      Dragoons     2nd     523        8   987       949          2
# Washington  Dragoons     2nd      62        3   849        48          3
# Oregon        Scouts     1st      62        4   973        48          2
# Wyoming       Scouts     1st      73        7  1005       435          1
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ### Step 11. Select every row up to the 4th row and all columns

# %%
df.iloc[:4, :]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2

# %% [markdown]
# ### Step 12. Select the 3rd column up to the 7th column

# %%
df.iloc [:,2:7]
# Out:
#             deaths  battles  size  veterans  readiness
# origin
# Arizona        523        5  1045         1          1
# California      52       42   957         5          2
# Texas           25        2  1099        62          3
# Florida        616        2  1400        26          3
# Maine           43        4  1592        73          2
# Iowa           234        7  1006        37          1
# Alaska         523        8   987       949          2
# Washington      62        3   849        48          3
# Oregon          62        4   973        48          2
# Wyoming         73        7  1005       435          1
# Louisana        37        8  1099        63          2
# Georgia         35        9  1523       345          3

# %% [markdown]
# ### Step 13. Select rows where df.deaths is greater than 50

# %%
 df [df ['deaths'] > 50]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# ...

# %%
mask = df ['deaths'] > 50

# %%
df[mask]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# ...

# %% [markdown]
# ### Step 14. Select rows where df.deaths is greater than 500 or less than 50

# %%
df [(df ['deaths'] < 50) | (df['deaths']> 500)]
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 6     Dragoons     2nd     523        8   987       949          2        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# 11      Scouts     2nd      35        9  1523       345          3        1
#
#     deserters    origin
# 0           4   Arizona
# 2          31     Texas
# 3           2   Florida
# 4           3     Maine
# 6          24    Alaska
# 10          2  Louisana
# 11          3   Georgia

# %% [markdown]
# ### Step 15. Select all the regiments not named "Dragoons"

# %%
mask = df['regiment'] != "Dragoons"

# %%
mask.values
# Out:
# array([ True,  True,  True,  True, False, False, False, False,  True,
#         True,  True,  True])

# %%
df[[ True,  True,  True,  True, False, False, False, False,  True,
        True,  True,  True]]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# ...

# %%
df [(df['regiment'] != "Dragoons")]
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# 11      Scouts     2nd      35        9  1523       345          3        1
#
#     deserters      origin
# 0           4     Arizona
# 1          24  California
# 2          31       Texas
# 3           2     Florida
# 8           2      Oregon
# 9           3     Wyoming
# 10          2    Louisana
# 11          3     Georgia

# %% [markdown]
# ### [__] Step 16. Select the rows called Texas and Arizona

# %%
##he tratado de sacar los valores Texas y Arizona poniendolos primero en los corchetes, de la columna origin, pero me da error. Al ser loc, hay que poner los nombres exactos, no sé por qué falla

# %%
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
df.loc[["Texas", "Arizona"], :]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas    Nighthawks     2nd      25        2  1099        62          3
# Arizona  Nighthawks     1st     523        5  1045         1          1
#
#          armored  deserters
# origin
# Texas          1         31
# Arizona        1          4

# %% [markdown]
# ### Step 17. Select the third cell in the row named Arizona

# %%
##no entiendo qué me pide. la tercera celda en origin es Arizona sí, ¿pero qué quiere que saque?

# %%
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
df.iloc[0, 2]
# Out:
# 523

# %%
df.loc['Arizona', 'deaths']
# Out:
# 523

# %% [markdown]
# ### Step 18. Select the third cell down in the column named deaths

# %%
df.iloc[-2,2]
# Out:
# 37

# %%
df.deaths. tail(3)
# Out:
# 9     73
# 10    37
# 11    35
# Name: deaths, dtype: int64
